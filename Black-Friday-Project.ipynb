# %%
import numpy as np
import pandas as pd

# %%
import os
for dirname,_,filenames in os.walk(r'E:\Datasets\Black_Friday'):
    for filename in filenames:
        print(os.path.join(dirname,filename))
# Out:
# E:\Datasets\Black_Friday\test.csv
# E:\Datasets\Black_Friday\train.csv

# %%
data = pd.read_csv(r"E:\Datasets\Black_Friday\train.csv")

# %%
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN      8370
# 1                      6.0                14.0     15200
# 2                      NaN                 NaN      1422
# 3                     14.0                 NaN      1057
# 4                      NaN                 NaN      7969
# ...                    ...                 ...       ...
# 550063                 NaN                 NaN       368
# 550064                 NaN                 NaN       371
# 550065                 NaN                 NaN       137
# 550066                 NaN                 NaN       365
# 550067                 NaN                 NaN       490
#
# [550068 rows x 12 columns]

# %% [markdown]
# #  Exploratory Data Analysis

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (550068, 12)

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %% [markdown]
# # Handle missing values with pandas

# %%
data.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
data.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df = data.fillna(method = 'pad')
# Out:
# C:\Users\suraj\AppData\Local\Temp\ipykernel_7628\2241967073.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = data.fillna(method = 'pad')

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            1
# Product_Category_3            1
# Purchase                      0
# dtype: int64

# %%
df[['Product_Category_2','Product_Category_3']].head()
# Out:
#    Product_Category_2  Product_Category_3
# 0                 NaN                 NaN
# 1                 6.0                14.0
# 2                 6.0                14.0
# 3                14.0                14.0
# 4                14.0                14.0

# %%
df = df.fillna(method = 'backfill')
# Out:
# C:\Users\suraj\AppData\Local\Temp\ipykernel_7628\3336528787.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method = 'backfill')

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
assert pd.notnull(df).all().all()

# %% [markdown]
# # Indexing and slicing in pandas

# %%
df1 = df.copy()

# %%
df1.loc[0]
# Out:
# User_ID                         1000001
# Product_ID                    P00069042
# Gender                                F
# Age                                0-17
# Occupation                           10
# City_Category                         A
# Stay_In_Current_City_Years            2
# Marital_Status                        0
# Product_Category_1                    3
# Product_Category_2                  6.0
# Product_Category_3                 14.0
# Purchase                           8370
# Name: 0, dtype: object

# %%
df1.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df1.loc[:,'Purchase'].head()
# Out:
# 0     8370
# 1    15200
# 2     1422
# 3     1057
# 4     7969
# Name: Purchase, dtype: int64

# %%
df1.loc[0:10,['Age','Occupation']]
# Out:
#       Age  Occupation
# 0    0-17          10
# 1    0-17          10
# 2    0-17          10
# 3    0-17          10
# 4     55+          16
# 5   26-35          15
# 6   46-50           7
# 7   46-50           7
# 8   46-50           7
# 9   26-35          20
# 10  26-35          20

# %%
df1.loc[[0, 1, 2, 3, 4],['Age','Occupation']]
# Out:
#     Age  Occupation
# 0  0-17          10
# 1  0-17          10
# 2  0-17          10
# 3  0-17          10
# 4   55+          16

# %%
df1.loc[0:5]
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
# 5                          3               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 6.0                14.0      8370
# 1                 6.0                14.0     15200
# 2                 6.0                14.0      1422
# 3                14.0                14.0      1057
# 4                14.0                14.0      7969
# 5                 2.0                14.0     15227

# %%
df1.iloc[0] # 1st rows of dataframe
# Out:
# User_ID                         1000001
# Product_ID                    P00069042
# Gender                                F
# Age                                0-17
# Occupation                           10
# City_Category                         A
# Stay_In_Current_City_Years            2
# Marital_Status                        0
# Product_Category_1                    3
# Product_Category_2                  6.0
# Product_Category_3                 14.0
# Purchase                           8370
# Name: 0, dtype: object

# %%
df1.iloc[-1] # 2nd rows of dataframe
# Out:
# User_ID                         1006039
# Product_ID                    P00371644
# Gender                                F
# Age                               46-50
# Occupation                            0
# City_Category                         B
# Stay_In_Current_City_Years           4+
# Marital_Status                        1
# Product_Category_1                   20
# Product_Category_2                  2.0
# Product_Category_3                 11.0
# Purchase                            490
# Name: 550067, dtype: object

# %% [markdown]
# # Multiple rows and columns selection using .iloc indexer

# %%
df1.iloc[0:5]
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 6.0                14.0      8370
# 1                 6.0                14.0     15200
# 2                 6.0                14.0      1422
# 3                14.0                14.0      1057
# 4                14.0                14.0      7969

# %%
# select first five columns of data frame with all rows¶
df1.iloc[:,0:5]
# Out:
#         User_ID Product_ID Gender    Age  Occupation
# 0       1000001  P00069042      F   0-17          10
# 1       1000001  P00248942      F   0-17          10
# 2       1000001  P00087842      F   0-17          10
# 3       1000001  P00085442      F   0-17          10
# 4       1000002  P00285442      M    55+          16
# ...         ...        ...    ...    ...         ...
# 550063  1006033  P00372445      M  51-55          13
# 550064  1006035  P00375436      F  26-35           1
# 550065  1006036  P00375436      F  26-35          15
# 550066  1006038  P00375436      F    55+           1
# 550067  1006039  P00371644      F  46-50           0
#
# [550068 rows x 5 columns]

# %%
# select 1st, 5th and 10th rows with 1st, 4th and 7th columns
df1.iloc[[0,4,9],[0,3,6]]
# Out:
#    User_ID    Age Stay_In_Current_City_Years
# 0  1000001   0-17                          2
# 4  1000002    55+                         4+
# 9  1000005  26-35                          1

# %%
# select first 5 rows and 5th, 6th, 7th columns of data frame
df1.iloc[0:5,5:8]
# Out:
#   City_Category Stay_In_Current_City_Years  Marital_Status
# 0             A                          2               0
# 1             A                          2               0
# 2             A                          2               0
# 3             A                          2               0
# 4             C                         4+               0

# %% [markdown]
# # Indexing first occurrence of maximum or minimum values with idxmax() and idxmin()

# %%
df1.loc[df1['Purchase'].idxmax()]
# Out:
# User_ID                         1001474
# Product_ID                    P00052842
# Gender                                M
# Age                               26-35
# Occupation                            4
# City_Category                         A
# Stay_In_Current_City_Years            2
# Marital_Status                        1
# Product_Category_1                   10
# Product_Category_2                 15.0
# Product_Category_3                  8.0
# Purchase                          23961
# Name: 87440, dtype: object

# %%
df1['Purchase'].idxmax()
# Out:
# 87440

# %% [markdown]
# # Indexing a single value with at() and iat()

# %%
df1.at[1,'Purchase']
# Out:
# 15200

# %%
# get value at 1st row and 11th column pair
df1.iat[1,11]
# Out:
# 15200

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 6.0                14.0      8370
# 1                 6.0                14.0     15200
# 2                 6.0                14.0      1422
# 3                14.0                14.0      1057
# 4                14.0                14.0      7969

# %% [markdown]
# # get the purchase amount with a given user_id and product_id

# %%
df2.loc[((df2['User_ID'] == 1000001) & (df2['Product_ID'] ==  'P00069042')),'Purchase']
# Out:
# 0    8370
# Name: Purchase, dtype: int64

# %% [markdown]
# # Indexing with isin() method

# %%
values = [1000001,'P00069042','F',0-17,10,'A',2,0,3,6,14,8370]
df2_indexed = df2.isin(values)
df2_indexed.head(10)
# Out:
#    User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0     True        True    True  False        True           True
# 1     True       False    True  False        True           True
# 2     True       False    True  False        True           True
# 3     True       False    True  False        True           True
# 4    False       False   False  False       False          False
# 5    False       False   False  False       False           True
# 6    False       False   False  False       False          False
# 7    False       False   False  False       False          False
# 8    False       False   False  False       False          False
# 9    False       False   False  False       False           True
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                       False            True                True
# 1                       False            True               False
# 2                       False            True               False
# 3                       False            True               False
# 4                       False            True               False
# 5                       False            True               False
# 6                       False           False               False
# 7                       False           False               False
# 8                       False           False               False
# 9                       False           False               False
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                True                True      True
# 1                True                True     False
# 2                True                True     False
# 3                True                True     False
# 4                True                True     False
# 5                True                True     False
# 6               False               False     False
# 7               False               False     False
# 8               False               False     False
# 9               False               False     False

# %%
df2
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      6.0                14.0      8370
# 1                      6.0                14.0     15200
# 2                      6.0                14.0      1422
# 3                     14.0                14.0      1057
# 4                     14.0                14.0      7969
# ...                    ...                 ...       ...
# 550063                 2.0                11.0       368
# 550064                 2.0                11.0       371
# 550065                 2.0                11.0       137
# 550066                 2.0                11.0       365
# 550067                 2.0                11.0       490
#
# [550068 rows x 12 columns]

# %%
df2_where = df2.where(df2 == 0)
df2_where.head(10)
# Out:
#    User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0      NaN        NaN    NaN  NaN         NaN           NaN
# 1      NaN        NaN    NaN  NaN         NaN           NaN
# 2      NaN        NaN    NaN  NaN         NaN           NaN
# 3      NaN        NaN    NaN  NaN         NaN           NaN
# 4      NaN        NaN    NaN  NaN         NaN           NaN
# 5      NaN        NaN    NaN  NaN         NaN           NaN
# 6      NaN        NaN    NaN  NaN         NaN           NaN
# 7      NaN        NaN    NaN  NaN         NaN           NaN
# 8      NaN        NaN    NaN  NaN         NaN           NaN
# 9      NaN        NaN    NaN  NaN         NaN           NaN
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                        NaN             0.0                 NaN
# 1                        NaN             0.0                 NaN
# 2                        NaN             0.0                 NaN
# 3                        NaN             0.0                 NaN
# 4                        NaN             0.0                 NaN
# 5                        NaN             0.0                 NaN
# 6                        NaN             NaN                 NaN
# 7                        NaN             NaN                 NaN
# 8                        NaN             NaN                 NaN
# 9                        NaN             NaN                 NaN
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN       NaN
# 1                 NaN                 NaN       NaN
# 2                 NaN                 NaN       NaN
# 3                 NaN                 NaN       NaN
# 4                 NaN                 NaN       NaN
# 5                 NaN                 NaN       NaN
# 6                 NaN                 NaN       NaN
# 7                 NaN                 NaN       NaN
# 8                 NaN                 NaN       NaN
# 9                 NaN                 NaN       NaN

# %%
df2.query('(Product_Category_1 > Product_Category_2) & (Product_Category_2 > Product_Category_3)')
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 165     1000033  P00111742      M  46-50           3             A
# 304     1000053  P00117542      M  26-35           0             B
# 351     1000058  P00288642      M  26-35           2             B
# 387     1000062  P00087242      F  36-45           3             A
# 724     1000137  P00124642      F  46-50           6             C
# ...         ...        ...    ...    ...         ...           ...
# 545338  1005954  P00327342      M  46-50          11             A
# 545339  1005954  P00087842      M  46-50          11             A
# 545461  1005972  P00255842      F  26-35          20             B
# 545747  1006016  P00058642      M  46-50           1             B
# 545896  1006037  P00183142      F  46-50           1             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 165                             1               1                  15
# 304                             1               0                  18
# 351                             3               0                  16
# 387                             1               0                  14
# 724                            4+               1                  16
# ...                           ...             ...                 ...
# 545338                          2               1                  16
# 545339                          2               1                  12
# 545461                          0               0                  16
# 545747                          1               1                  18
# 545896                         4+               0                  15
#
#         Product_Category_2  Product_Category_3  Purchase
# 165                    8.0                 5.0     17391
# 304                   16.0                 5.0      3794
# 351                   14.0                12.0     16579
# 387                   12.0                 6.0     11279
# 724                   14.0                 6.0     16828
# ...                    ...                 ...       ...
# 545338                11.0                 5.0     12330
# 545339                11.0                 5.0       343
# 545461                11.0                 5.0     20634
# 545747                14.0                12.0      3018
# 545896                14.0                13.0     13054
#
# [2278 rows x 12 columns]

# %% [markdown]
# # Indexing and reindexing in pandas

# %%
food = pd.DataFrame({'Place':['Home', 'Home', 'Hotel', 'Hotel'],
                   'Time': ['Lunch', 'Dinner', 'Lunch', 'Dinner'],
                   'Food':['Soup', 'Rice', 'Soup', 'Chapati'],
                   'Price($)':[10, 20, 30, 40]})

# %%
food
# Out:
#    Place    Time     Food  Price($)
# 0   Home   Lunch     Soup        10
# 1   Home  Dinner     Rice        20
# 2  Hotel   Lunch     Soup        30
# 3  Hotel  Dinner  Chapati        40

# %%
food_indexed1 = food.set_index('Place')
food_indexed1
# Out:
#          Time     Food  Price($)
# Place
# Home    Lunch     Soup        10
# Home   Dinner     Rice        20
# Hotel   Lunch     Soup        30
# Hotel  Dinner  Chapati        40

# %%
food_indexed2 = food.set_index(['Place','Time'])
food_indexed2
# Out:
#                  Food  Price($)
# Place Time
# Home  Lunch      Soup        10
#       Dinner     Rice        20
# Hotel Lunch      Soup        30
#       Dinner  Chapati        40
